# %% [markdown]
# # regresion-abalone
#
# Notebook de partida. Carga los datos, explora, entrena tu modelo y genera `mi_prediccion.csv`.
#
# Objetivo: predecir `Rings` (número de anillos, relacionado con la edad del abalón) a partir de medidas físicas. La métrica de calificación es **RMSE**.

# %%
import pandas as pd

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
train.head()
# Out:
#    id Sex  Length  Diameter  Height  Whole_weight  Shucked_weight  \
# 0   0   M   0.455     0.365   0.095        0.5140          0.2245
# 1   1   M   0.350     0.265   0.090        0.2255          0.0995
# 2   2   F   0.530     0.420   0.135        0.6770          0.2565
# 3   3   M   0.440     0.365   0.125        0.5160          0.2155
# 4   4   I   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera_weight  Shell_weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
train.info()
train.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3341 entries, 0 to 3340
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              3341 non-null   int64
#  1   Sex             3341 non-null   str
#  2   Length          3341 non-null   float64
#  3   Diameter        3341 non-null   float64
#  4   Height          3341 non-null   float64
#  5   Whole_weight    3341 non-null   float64
#  6   Shucked_weight  3341 non-null   float64
#  7   Viscera_weight  3341 non-null   float64
#  8   Shell_weight    3341 non-null   float64
#  9   Rings           3341 non-null   int64
# dtypes: float64(7), int64(2), str(1)
# memory usage: 261.1 KB
#                 id       Length     Diameter       Height  Whole_weight  \
# count  3341.000000  3341.000000  3341.000000  3341.000000   3341.000000
# mean   2116.754565     0.524964     0.408518     0.139790      0.830838
# ...

# %% [markdown]
# ## Exploración rápida
#
# `Sex` es una variable categórica (`M`, `F`, `I`); el resto son medidas numéricas. Antes de entrenar necesitas decidir cómo representar `Sex` en un modelo (por ejemplo, `pd.get_dummies`).

# %%
train["Sex"].value_counts()
# Out:
# Sex
# M    1221
# I    1075
# F    1045
# Name: count, dtype: int64

# %%
# TODO: features, entrenamiento, validación
#
# Sugerencias:
# 1. Convierte 'Sex' a variables dummy (pd.get_dummies) tanto en train como en test.
# 2. Separa un conjunto de validación desde train (train_test_split) para
#    estimar tu RMSE antes de enviar tu entrega.
# 3. Entrena un modelo de regresión (LinearRegression, RandomForestRegressor, etc.)
# 4. Calcula el RMSE de validación con sklearn.metrics.mean_squared_error.
# 5. Cuando estés conforme, reentrena con todo 'train' y predice sobre 'test'.

# %%
# Genera el CSV de submission
# predictions = pd.DataFrame({"id": test["id"], "Rings": y_pred})
# predictions.to_csv("mi_prediccion.csv", index=False)
