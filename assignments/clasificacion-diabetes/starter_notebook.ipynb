# %% [markdown]
# # clasificacion-diabetes
#
# Notebook de partida. Carga los datos, explora, entrena tu modelo y genera `mi_prediccion.csv`.

# %%
import pandas as pd

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
train.head()
# Out:
#    id  preg  plas  pres  skin  insu  mass   pedi  age            class
# 0   0     6   148    72    35     0  33.6  0.627   50  tested_positive
# 1   1     1    85    66    29     0  26.6  0.351   31  tested_negative
# 2   2     8   183    64     0     0  23.3  0.672   32  tested_positive
# 3   4     0   137    40    35   168  43.1  2.288   33  tested_positive
# 4   5     5   116    74     0     0  25.6  0.201   30  tested_negative

# %%
# TODO: features, entrenamiento, validación

# %%
# Genera el CSV de submission
# predictions = pd.DataFrame({"id": test["id"], "class": y_pred})
# predictions.to_csv("mi_prediccion.csv", index=False)
