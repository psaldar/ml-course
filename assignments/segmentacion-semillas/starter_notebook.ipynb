# %% [markdown]
# # segmentacion-semillas
#
# Notebook de partida. Carga los datos, explora, agrupa los granos en
# clusters (**sin usar la columna `variedad`**) y genera `mi_prediccion.csv`
# con columnas `id,cluster`.
#
# Recuerda: este es un problema de **clustering no supervisado**. La
# columna `variedad` en `train.csv` es solo para que valides tu intuición
# explorando los datos — no la uses como input de tu algoritmo de
# clustering, y por supuesto no existe en `test.csv`.

# %%
import pandas as pd

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
train.head()
# Out:
#    id   area  perimetro  compacidad  longitud_nucleo  ancho_nucleo  \
# 0   0  15.26      14.84      0.8710            5.763         3.312
# 1   3  13.84      13.94      0.8955            5.324         3.379
# 2   4  16.14      14.99      0.9034            5.658         3.562
# 3   5  14.38      14.21      0.8951            5.386         3.312
# 4   6  14.69      14.49      0.8799            5.563         3.259
#
#    coef_asimetria  longitud_surco  variedad
# 0           2.221           5.220         1
# 1           2.259           4.805         1
# 2           1.355           5.175         1
# 3           2.462           4.956         1
# 4           3.586           5.219         1

# %% [markdown]
# ## Exploración
#
# Explora las variables geométricas, revisa si `variedad` (solo visible en
# `train.csv`) separa bien los datos en el espacio de las variables
# originales o en un PCA a 2D. Esto es solo para construir intuición.

# %%
# TODO: exploración (describe, pairplot/scatter, PCA a 2D coloreando por variedad, etc.)

# %% [markdown]
# ## Clustering
#
# Aplica un algoritmo de clustering (K-Means, jerárquico, DBSCAN, ...) sobre
# las variables numéricas de `train` + `test` combinadas (o ajusta sobre
# `train` y predice sobre `test`, según el algoritmo). Recuerda **estandarizar**
# las variables antes de aplicar el algoritmo, y elegir un número de
# clusters razonable (aquí sabemos que hay 3 variedades, pero en un caso
# real tendrías que decidirlo con el método del codo o el coeficiente de
# silueta).

# %%
# TODO: escalar variables, ajustar el algoritmo de clustering, generar la asignación de cluster para test

# %%
# Genera el CSV de submission
# predictions = pd.DataFrame({"id": test["id"], "cluster": cluster_labels})
# predictions.to_csv("mi_prediccion.csv", index=False)
