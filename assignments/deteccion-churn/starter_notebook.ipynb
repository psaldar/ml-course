# %% [markdown]
# # deteccion-churn
#
# Notebook de partida. Carga los datos, explora, entrena tu modelo y genera `mi_prediccion.csv`.

# %%
import pandas as pd

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
train.head()
# Out:
#    id  state  account_length  area_code  phone_number  international_plan  \
# 0   0     16             128        415          2845                   0
# 1   1     35             107        415          2301                   0
# 2   2     31             137        415          1616                   0
# 3   3     35              84        408          2510                   1
# 4   5      1             118        510          3355                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              223.4               98
#
#    ...  total_eve_calls  total_eve_charge  total_night_minutes  \
# 0  ...               99             16.78                244.7
# 1  ...              103             16.62                254.4
# 2  ...              110             10.30                162.6
# 3  ...               88              5.26                196.9
# 4  ...              101             18.75                203.9
#
#    total_night_calls  total_night_charge  total_intl_minutes  \
# 0                 91               11.01                10.0
# 1                103               11.45                13.7
# 2                104                7.32                12.2
# 3                 89                8.86                 6.6
# 4                118                9.18                 6.3
#
#    total_intl_calls  total_intl_charge  number_customer_service_calls  class
# 0                 3               2.70                              1      0
# 1                 3               3.70                              1      0
# 2                 5               3.29                              0      0
# 3                 7               1.78                              2      0
# 4                 6               1.70                              0      0
#
# [5 rows x 22 columns]

# %%
# TODO: features, entrenamiento, validación

# %%
# Genera el CSV de submission
# predictions = pd.DataFrame({"id": test["id"], "class": y_pred})
# predictions.to_csv("mi_prediccion.csv", index=False)
